# %% [markdown]
# # Actividad de lectura de archivos.
# ## Juan Manuel González Ascencio - A00572003

# %%
import pandas as pd

# %%
#Leer el archivo encuesta.txt

encuesta = pd.read_csv('encuesta.txt', delim_whitespace= True,)
encuesta
# Out:
#                                   ID  asistio  Tarea  Comportamiento Pago
# 0    cef3615d61b202f1dc794ef2746df14        1    1.0             0.0   si
# 1    323e5a13644d18185c743c241407754        0    0.0             NaN   no
# 2    b29a107e5cd062e654a63764157461d        0    0.0             NaN   no
# 3   04a11e4bcb573a1261eb0d9948d32637        1    0.0             0.0   si
# 4    9368291c3d5d5f5c8cdb1a575e18bec        1    0.0             0.0   si
# 5    dd0e77eab270e4b67c19b0d6bbf621b        0    0.0             NaN   no
# 6    7599c0aa419b59fd11ffede98a3665d        0    0.0             NaN   si
# 7    6dff182b452487f07a47596f314bddc        0    1.0             NaN   si
# 8    9dc233fed1c6eb2432672ab4bb39249        0    0.0             NaN   no
# 9   265fa78a1fb2409ff5416aec3c4f950d        1    0.0             0.0   si
# 10  3b461f95fe50be35b927c255b3f7dc3a        1    1.0             1.0   no
# 11  e786f1288887afb309eb913d28ffd6b0        1    0.0             0.0   si
# ...

# %% [markdown]
# Convertimos las variables que contengan 0 u 1 a valores booleanos

# %%
df = pd.read_csv('encuesta.txt',
                 delim_whitespace=True,
                 dtype={'asistio': bool, 'Tarea': bool, 'Pago': bool}, true_values=['si'], false_values=['no'])
df
# Out:
#                                   ID  asistio  Tarea  Comportamiento   Pago
# 0    cef3615d61b202f1dc794ef2746df14     True   True             0.0   True
# 1    323e5a13644d18185c743c241407754    False  False             NaN  False
# 2    b29a107e5cd062e654a63764157461d    False  False             NaN  False
# 3   04a11e4bcb573a1261eb0d9948d32637     True  False             0.0   True
# 4    9368291c3d5d5f5c8cdb1a575e18bec     True  False             0.0   True
# 5    dd0e77eab270e4b67c19b0d6bbf621b    False  False             NaN  False
# 6    7599c0aa419b59fd11ffede98a3665d    False  False             NaN   True
# 7    6dff182b452487f07a47596f314bddc    False   True             NaN   True
# 8    9dc233fed1c6eb2432672ab4bb39249    False  False             NaN  False
# 9   265fa78a1fb2409ff5416aec3c4f950d     True  False             0.0   True
# 10  3b461f95fe50be35b927c255b3f7dc3a     True   True             1.0  False
# ...

# %%
# %%time
#convertir a csv

df = pd.read_csv('data.csv', delim_whitespace=True, )
df
# Out:
# CPU times: user 356 ms, sys: 19.6 ms, total: 375 ms
# Wall time: 382 ms
#                                                                            Age|Sex|ID|Race|Country|Education|Education-Num|Marital  \
# 39.0| Male|49084|       White|              United-States| Bachelors|13.0|                                     Never-married|
# 50.0| Male|68553|       White|              United-States| Bachelors|13.0|                                Married-civ-spouse|
# 38.0| Male|143654|      White|              United-States| HS-grad|9.0|                                             Divorced|
# 53.0| Male|41510|       Black|              United-States| 11th|7.0|                                      Married-civ-spouse|
# 28.0| Female|195025|    Black|              Cuba|          Bachelors|13.0|                                Married-civ-spouse|
# ...                                                                                                                       ...
# ...
