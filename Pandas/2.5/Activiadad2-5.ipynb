# %% [markdown]
# # Actividad 2.5 - Transformación de datos.
# ## Juan Manuel González Ascencio - A00572003
# -------
#
# # Instrucciones
# ## P1. Escalamiento. Feature scaling con los datos del archivo NBALinks to an external site.:
# - Genera el DataFrame de la tabla stats.
# - Realiza limpieza, y preprocesamiento de modo que contemos con solamente los valores numéricos (no nulos). Pista: Puedes eliminar columnas con muchos valores faltantes.
# - Analiza los resultados de análisis usando las técnicas de Escalamiento de esta sesión y reporta tus observaciones en una tabla enfocándose en:
#     - ¿Qué sucede con la media?
#     - ¿Qué sucede con la mediana?
#     - ¿Qué sucede con los mínimos y máximos?
#     - ¿Qué sucede con la desviación estándar?
# ## P2. Discretizacion.
# - Seguimos trabajando con los datos de Stats.
# - A partir de la variable PTS, crea otras variables PTS_categories_(metodo) que refleje 4 intervalos segun los métodos between & loc, cut y qcut vistos en esta sesión. Dichos bins deben estar basados en los cuartiles (Q1, Q2, Q3, Q4).

# %%
import pandas as pd
import missingno as msno

# %%
#Genera el DataFrame de la tabla stats.

df = pd.read_excel('NBA.xlsx', sheet_name='stats')
df.head()
# Out:
#    X1    Year           Player  Pos   Age   Tm     G  GS  MP  PER  ...    FT%  \
# 0   0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  ...  0.705
# 1   1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  ...  0.708
# 2   2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  ...  0.698
# 3   3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  ...  0.559
# 4   4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  ...  0.548
#
#    ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
#Realiza limpieza, y preprocesamiento de modo que contemos con solamente los valores numéricos (no nulos). Pista: Puedes eliminar columnas con muchos valores faltantes.

msno.matrix(df)
# Out:
# <Axes: >

# %%
#Borramos las columnas con valores nulos
#df = df.drop(columns=['ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%','BLK%', 'TOV%', 'USG%', 'blanl'])
#df = df.drop(columns = ['blank2', 'OBPM', 'DBPM', 'BPM','ORB','DRB', 'STL','BLK', 'TOV'])
msno.matrix(df)
#resumen de la columna GS

df['GS'].describe()
# Out:
# count    6247.000000
# mean        0.173203
# std         0.378453
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: GS, dtype: float64

# %%
#Analiza los resultados de análisis usando las técnicas de Escalamiento
