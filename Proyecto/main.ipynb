# %%
import pandas as pd 
import missingno as msno

# %%
#cargamos los datos en data frames 

df = pd.read_excel('Solo liverpool.xlsx')
df.head()
# Out:
#      Order # Order Status Invoice Status Shipper Cmp ID  \
# 0  1346469.0          CMP            XIN       CDTLIVTL
# 1  1346470.0          CMP            XIN       CDTLIVTL
# 2  1346485.0          CMP            XIN       CDTLIVTL
# 3  1347960.0          CMP            PPD         ENCMON
# 4  1346187.0          CMP            AVL       PLANTECA
#
#            Shipper Company  Shipper City Shipper State Consignee Cmp ID  \
# 0  BOD LIVERPOOL TULTITLAN  TULTITLAN,EM            EM          LIVPLAN
# 1  BOD LIVERPOOL TULTITLAN  TULTITLAN,EM            EM          LIVPLAN
# 2  BOD LIVERPOOL TULTITLAN  TULTITLAN,EM            EM          LIVPLAN
# 3  ENCO GNV BERNARDO REYES  MONTERREY,NX            NX           ENCMON
# 4           PLANTA TECAMAC    TECAMAC,EM            EM         BODIZT02
#
#                                    Consignee Company Consignee City  ...  \
# 0  PLAN LIVERPOOL (PLATAFORMA LOGÍSTICA ARCO NORT...   JILOTEPEC,EM  ...
# ...

# %%
df.describe()
# Out:
#             Order #               Order Start Date  \
# count  1.530000e+02                            154
# mean   1.346959e+06  2024-02-13 06:38:52.207792128
# min    1.343187e+06            2024-02-13 00:00:00
# 25%    1.346551e+06            2024-02-13 02:00:00
# 50%    1.347204e+06            2024-02-13 06:36:00
# 75%    1.347298e+06            2024-02-13 09:15:00
# max    1.349049e+06            2024-02-14 00:45:00
# std    7.376398e+02                            NaN
#
#                Order Completion Date  Line Haul Charge  Accessorial Charge  \
# count                            154        153.000000               153.0
# mean   2024-02-13 08:19:00.779220992       5015.959608                 0.0
# min              2024-02-13 00:08:00          0.000000                 0.0
# 25%              2024-02-13 06:01:15          0.010000                 0.0
# 50%              2024-02-13 08:00:00          0.010000                 0.0
# ...

# %%
#visualizamos los datos faltantes

msno.matrix(df)
# Out:
# <Axes: >

# %%
#imprimimos la columna carrier rep para ver si es util dejarla

print(df['Carrier Rep'])

#eliminamos carrier rep

df = df.drop(['Carrier Rep'], axis=1)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3      UNKNOWN
# 4      UNKNOWN
#         ...
# 149        NaN
# 150        NaN
# 151        NaN
# 152        NaN
# 153        NaN
# Name: Carrier Rep, Length: 154, dtype: object

# %%
# vemos cuantos datos no null hay en cada columna

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order #                153 non-null    float64
#  1   Order Status           154 non-null    object
#  2   Invoice Status         154 non-null    object
#  3   Shipper Cmp ID         154 non-null    object
#  4   Shipper Company        154 non-null    object
#  5   Shipper City           154 non-null    object
#  6   Shipper State          154 non-null    object
#  7   Consignee Cmp ID       154 non-null    object
#  8   Consignee Company      154 non-null    object
#  9   Consignee City         154 non-null    object
#  10  Consignee State        154 non-null    object
#  11  Order By Cmp ID        153 non-null    object
#  12  Order By Company       154 non-null    object
#  13  Order By City, State   154 non-null    object
# ...

# %%
#eliminamos las ultimas tres columnas 

df = df.drop(['Carrier Pay', ''], axis=1)
